# %% [markdown]
# Our first approach is to use bagging with decision trees.

# %%
# let's make the basic imports

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi']= 180 # set the resolution to x dpi

data = pd.read_csv("test_cleaned.csv")
# data = pd.read_csv("finalDataSet.csv")
data.describe()
# Out:
#              new_x0        new_x1        new_x2        new_x3        new_x4  \
# count  9.930000e+02  9.930000e+02  9.930000e+02  9.930000e+02  9.930000e+02
# mean  -1.754219e-16 -9.693488e-17 -4.514124e-17 -5.440708e-17 -8.240024e-17
# std    5.718176e-01  5.265950e-01  5.085137e-01  4.869818e-01  4.712309e-01
# min   -9.047528e-01 -9.817048e-01 -1.091984e+00 -9.572631e-01 -1.107336e+00
# 25%   -6.145996e-01 -3.974075e-01 -3.859744e-01 -3.255558e-01 -3.481292e-01
# 50%    9.914812e-02 -1.528587e-01 -6.682220e-02 -2.087775e-02  5.960585e-03
# 75%    4.614965e-01  5.326962e-01  4.027341e-01  2.769022e-01  3.112992e-01
# max    1.084350e+00  1.059547e+00  1.205222e+00  1.337632e+00  1.258942e+00
#
#              new_x5        new_x6        new_x7        new_x8        new_x9  \
# count  9.930000e+02  9.930000e+02  9.930000e+02  9.930000e+02  9.930000e+02
# mean  -8.645317e-17 -6.193994e-17  2.761582e-17 -1.234047e-16  5.310735e-19
# ...

# %%
# We split the data into training and testing
from sklearn.model_selection import train_test_split

test_size = 0.2
train, test = train_test_split(data,test_size=test_size,shuffle=True)

# %%
print(train.shape,test.shape)
print(np.sum(np.sum(train.isnull())),np.sum(np.sum(train.isnull())))
# Out:
# (794, 26) (199, 26)
# 0 0

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    "criterion":["gini","entropy"],
    "max_depth" : list(range(2,train.shape[1]-1,2)) + [None]}

classifier = GridSearchCV(DecisionTreeClassifier,param_grid,n_jobs=-1)
features,target = (train.iloc[:,:-1],train.iloc[:,-1].astype(int))
print(features.shape,target.shape)
classifier.fit(features,target.ravel())
# Out:
# (794, 25) (794,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a0393f9c86f9> in <module>
#      10 features,target = (train.iloc[:,:-1],train.iloc[:,-1].astype(int))
#      11 print(features.shape,target.shape)
# ---> 12 classifier.fit(features,target.ravel())
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     653         n_splits = cv.get_n_splits(X, y, groups)
#     654
# --> 655         base_estimator = clone(self.estimator)
#     656
#     657         parallel = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in clone(estimator, safe)
#      65                             "it does not seem to be a scikit-learn estimator "
#      66                             "as it does not implement a 'get_params' methods."
# ...
